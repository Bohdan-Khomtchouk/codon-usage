# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
vrl_df = pd.read_csv("../heatmap_inputs/vrl_data.csv", index_col=0)
phg_df = pd.read_csv("../heatmap_inputs/phg_data.csv", index_col=0)
bct_df = pd.read_csv("../heatmap_inputs/bct_data.csv", index_col=0)
arc_df = pd.read_csv("../heatmap_inputs/arc_data.csv", index_col=0)
euk_df = pd.read_csv("../heatmap_inputs/euk_data.csv", index_col=0)

# %%
vrl_df.head(5)
# Out:
#           UUU      UUC      UUA      UUG      CUU      CUC      CUA      CUG  \
# Name
# 1     0.01654  0.01203  0.00050  0.00351  0.01203  0.03208  0.00100  0.04010
# 2     0.02714  0.01357  0.00068  0.00678  0.00407  0.02849  0.00204  0.04410
# 3     0.01974  0.02180  0.01357  0.01543  0.00782  0.01111  0.01028  0.01193
# 4     0.01775  0.02245  0.01619  0.00992  0.01567  0.01358  0.00940  0.01723
# 5     0.02816  0.01371  0.00767  0.03679  0.01380  0.00548  0.00473  0.02076
#
#           AUU      AUC   ...         CGG      AGA      AGG      GAU      GAC  \
# Name                     ...
# 1     0.00551  0.02005   ...     0.00451  0.01303  0.03559  0.01003  0.04612
# 2     0.01153  0.02510   ...     0.00136  0.01696  0.03596  0.01221  0.04545
# 3     0.02283  0.01604   ...     0.00596  0.01974  0.02489  0.03126  0.02036
# 4     0.02402  0.02245   ...     0.00366  0.01410  0.01671  0.03760  0.01932
# 5     0.02716  0.00867   ...     0.00604  0.01494  0.01734  0.04148  0.02483
#
#           GAA      GAG      UAA      UAG      UGA
# Name
# 1     0.01203  0.04361  0.00251  0.00050  0.00000
# 2     0.01560  0.04410  0.00271  0.00068  0.00000
# 3     0.02242  0.02468  0.00391  0.00000  0.00144
# 4     0.03029  0.03446  0.00261  0.00157  0.00000
# 5     0.03359  0.03679  0.00000  0.00044  0.00131
#
# [5 rows x 64 columns]

# %%
#Heatmaps without normalizing 

fig,(ax1,ax2, ax3, ax4, ax5) = plt.subplots(5, 1, figsize=(10,10))

g1 = sns.heatmap(vrl_df, cbar=False, ax=ax1)
ax1.title.set_text('vrl')
g2 = sns.heatmap(phg_df, cbar=False, ax=ax2)
ax2.title.set_text('phg')
g3 = sns.heatmap(bct_df, cbar=False, ax=ax3)
ax3.title.set_text('bct')
g4 = sns.heatmap(arc_df, cbar=False, ax=ax4)
ax4.title.set_text('arc')
g5 = sns.heatmap(euk_df, cbar=False, ax=ax5)
ax5.title.set_text('euk')

fig.tight_layout()

# %%
#Heatmaps after normalizing 
fig,(ax1,ax2, ax3, ax4, ax5) = plt.subplots(5, 1, figsize=(10,10))

g1 = sns.heatmap(vrl_df,vmin=0, vmax=0.27543, cbar=False, ax=ax1)
ax1.title.set_text('vrl')
g2 = sns.heatmap(phg_df,vmin=0, vmax=0.27543, cbar=False, ax=ax2)
ax2.title.set_text('phg')
g3 = sns.heatmap(bct_df,vmin=0, vmax=0.27543, cbar=False, ax=ax3)
ax3.title.set_text('bct')
g4 = sns.heatmap(arc_df,vmin=0, vmax=0.27543, cbar=False, ax=ax4)
ax4.title.set_text('arc')
g5 = sns.heatmap(euk_df,vmin=0, vmax=0.27543, cbar=False, ax=ax5)
ax5.title.set_text('euk')

fig.tight_layout()
